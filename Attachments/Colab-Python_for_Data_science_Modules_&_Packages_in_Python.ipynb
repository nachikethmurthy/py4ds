# %% [markdown]
# # Modules in Pyton Programming

# %% [markdown]
# ## User Defined Modules

# %%
#Get the file from github
# !wget https://raw.githubusercontent.com/manifoldailearning/Deeplearning-BootCamp/main/food.py
# Out:
# --2021-12-27 02:31:08--  https://raw.githubusercontent.com/manifoldailearning/Deeplearning-BootCamp/main/food.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 239 [text/plain]
# Saving to: ‘food.py’
#
# food.py             100%[===================>]     239  --.-KB/s    in 0s
#
# 2021-12-27 02:31:09 (8.51 MB/s) - ‘food.py’ saved [239/239]

# %%
import food # import the entire Module

# %%
place = food.pick()
print(f"Lets go to {place}")
# Out:
# Lets go to McDonalds

# %%
from food import pick # Import Specific function from a module

# %%
place = pick()
print(f"Lets go to {place}")
# Out:
# Lets go to Taco Bell

# %%
# import with another name
import food as hunger

# %%
place = hunger.pick()
print(f"Lets go to {place}")
# Out:
# Lets go to Wendys

# %%
# Import all from a module
from food import *
place = pick()
print(f"Lets go to {place}")
# Out:
# Lets go to Arbys

# %%
import shutil # More on Future 
import os

#Create a copy of my module
shutil.copy("food.py","fast_food.py")

#Create new Folder
os.mkdir("Module")

#Move newly created module to a new folder
shutil.move("/content/fast_food.py","/content/Module/fast_food.py")
# Out:
# '/content/Module/fast_food.py'

# %%
#Try Importing new module
import fast_food
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-699a1b109223> in <module>()
#       1 #Try Importing new module
# ----> 2 import fast_food
#
# ModuleNotFoundError: No module named 'fast_food'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Module Search Path

# %%
import sys
for place in sys.path:
  print(place)
# Out:
# /content
# /env/python
# /usr/lib/python37.zip
# /usr/lib/python3.7
# /usr/lib/python3.7/lib-dynload
# /usr/local/lib/python3.7/dist-packages
# /usr/lib/python3/dist-packages
# /usr/local/lib/python3.7/dist-packages/IPython/extensions
# /root/.ipython

# %%
#/content/Module/fast_food.py

# %%
#Add a new search path and make it to look first
sys.path.insert(0,"/content/Module")

# %%
for place in sys.path:
  print(place)
# Out:
# /content/Module
#
# /content
# /env/python
# /usr/lib/python37.zip
# /usr/lib/python3.7
# /usr/lib/python3.7/lib-dynload
# /usr/local/lib/python3.7/dist-packages
# /usr/lib/python3/dist-packages
# /usr/local/lib/python3.7/dist-packages/IPython/extensions
# /root/.ipython

# %%
import fast_food

# %%
place = fast_food.pick()
print(f"Lets go to {place}")
# Out:
# Lets go to Burger King

# %% [markdown]
# ## Built-in Modules

# %%
import math
x = math.log10(10)
x
# Out:
# 1.0

# %%
from math import log2
x = log2(10)
x
# Out:
# 3.321928094887362

# %% [markdown]
# # Packages in Python Programming

# %% [markdown]
# A `Package` is a subdirectory that contains `.py` files. We can also create directories inside it

# %%
#get another python file for practice
# !wget https://raw.githubusercontent.com/manifoldailearning/Deeplearning-BootCamp/main/add_multiply.py
# Out:
# --2021-12-27 02:37:42--  https://raw.githubusercontent.com/manifoldailearning/Deeplearning-BootCamp/main/add_multiply.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 67 [text/plain]
# Saving to: ‘add_multiply.py’
#
# add_multiply.py     100%[===================>]      67  --.-KB/s    in 0s
#
# 2021-12-27 02:37:42 (3.33 MB/s) - ‘add_multiply.py’ saved [67/67]

# %%
import shutil # More on Future 
import os

#Create new Folder
os.mkdir("MyPackage")
os.mkdir("/content/MyPackage/math")

#Create a copy of my module
shutil.copy("food.py","fast_food.py")

#Move newly created module to a new folder
shutil.move("/content/fast_food.py","/content/MyPackage/fast_food.py")

shutil.move("/content/add_multiply.py","/content/MyPackage/math/add_multiply.py")
# Out:
# '/content/MyPackage/math/add_multiply.py'

# %%
#While working import modules from Packages
from MyPackage import fast_food

# %%
fast_food.pick()
# Out:
# 'Wendys'

# %%
from MyPackage.math import add_multiply

# %%
add_multiply.add(5,7)
# Out:
# 12

# %%
from MyPackage import add
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-24-e47dceaaf69a> in <module>()
# ----> 1 from MyPackage import add
#
# ImportError: cannot import name 'add' from 'MyPackage' (unknown location)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # `__init__.py` file
#
# The package folder contains a special file called __init__.py, which stores the package's content. It serves two purposes:
#
# 1. The Python interpreter recognizes a folder as the package if it contains __init__.py file. (This is Optional from Python 3.3+) **interview question**
# 2. __init__.py exposes specified resources from its modules to be imported.

# %%
#Lets get our __init__ file and place it inside our Package folder

# %%
# !wget https://raw.githubusercontent.com/manifoldailearning/Deeplearning-BootCamp/main/__init__.py
#Get the file from github
# !wget https://raw.githubusercontent.com/manifoldailearning/Deeplearning-BootCamp/main/food.py
#get another python file for practice
# !wget https://raw.githubusercontent.com/manifoldailearning/Deeplearning-BootCamp/main/add_multiply.py
# Out:
# --2021-12-27 02:40:55--  https://raw.githubusercontent.com/manifoldailearning/Deeplearning-BootCamp/main/__init__.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 288 [text/plain]
# Saving to: ‘__init__.py’
#
# __init__.py         100%[===================>]     288  --.-KB/s    in 0s
#
# 2021-12-27 02:40:55 (12.4 MB/s) - ‘__init__.py’ saved [288/288]
#
# --2021-12-27 02:40:55--  https://raw.githubusercontent.com/manifoldailearning/Deeplearning-BootCamp/main/food.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
import shutil # More on Future 
import os

#Create new Folder
# os.mkdir("MyPackage")
# os.mkdir("/content/MyPackage/math")

#Create a copy of my module
shutil.copy("food.py","fast_food.py")

#Move newly created module to a new folder
shutil.move("/content/fast_food.py","/content/MyPackage/fast_food.py")

shutil.move("/content/add_multiply.py","/content/MyPackage/math/add_multiply.py")

#Move
shutil.move("/content/__init__.py","/content/MyPackage/__init__.py")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/lib/python3.7/shutil.py in move(src, dst, copy_function)
#     565     try:
# --> 566         os.rename(src, real_dst)
#     567     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/add_multiply.py' -> '/content/MyPackage/math/add_multiply.py'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-a39cfba3af31> in <module>()
#      12 shutil.move("/content/fast_food.py","/content/MyPackage/fast_food.py")
#      13
# ---> 14 shutil.move("/content/add_multiply.py","/content/MyPackage/math/add_multiply.py")
#      15
#      16 #Move
#
# /usr/lib/python3.7/shutil.py in move(src, dst, copy_function)
#     578             rmtree(src)
#     579         else:
# ...

# %%
import MyPackage

# %%
from MyPackage import add,multiply,pick
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-34-cbfc00e1d529> in <module>()
# ----> 1 from MyPackage import add,multiply,pick
#
# ImportError: cannot import name 'add' from 'MyPackage' (unknown location)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pick()
# Out:
# 'Wendys'

# %%
add(5,7)
# Out:
# 12

# %%
multiply(5,8)
# Out:
# 40

# %%
add(5,6)

# %% [markdown]
# # Example of Sklearn Package

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### init file
#
# ![image.png](data:image/png;base64,...)
